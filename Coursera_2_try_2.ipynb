# %%
from math import sin, exp
from scipy.linalg import solve
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return sin(x/5.0)*exp(x/10.0) + 5*exp(-x/2.0)

x1 = 1.0
x2 = 15.0

x_list = []
y_list = []
n = np.arange(1.0, 15.0, 0.1);
for x in n:
    x_list.append(x)
    y_list.append(f(x))

plt.plot(x_list, y_list)
plt.show()

# %% [raw]
# 4.36264153512 -1.29552586569 0.193336847022 -0.00823565117332 правильный ответ
# 2.94378905    -1.32450651    0.2303422      -0.01022753 мой ответ. ошибка в W[0]?

# %%
x1 = 1.0
x2 = 4.0
x3 = 10.0
x4 = 15.0

def approx_third_f(x, W):
#     W[0] = 4.36264153512
#     W[1] = -1.29552586569
#     W[2] = 0.193336847022
#     W[3] = -0.00823565117332
    return W[0] + W[1]*x + W[2]*x**2 + W[3]*x**3

A = np.array([[1, x1, x1**2, x1**3],[1, x2, x2**2, x2**3], [1, x3, x3**2, x3**3], [1, x4, x4**2, x4**3]])
B = np.array([f(x1), f(x2), f(x3), f(x4)])
W = solve(A, B)
print(W)
print(f(x1), f(x2), f(x3), f(x4))

x_list = []
y_list = []
n = np.arange(1.0, 15.0, 0.1);
for x in n:
    x_list.append(x)
    y_list.append(approx_third_f(x, W))

plt.plot(x_list, y_list)
plt.show()
# Out:
# [ 4.36264154 -1.29552587  0.19333685 -0.00823565]
# (3.252216865271419, 1.7468459495903677, 2.5054164070002463, 0.6352214195786656)
